# %%
from ultralytics import YOLO
import cv2

# load pretrained YOLOv8 nano model
model = YOLO("yolov8n.pt")

# run inference on an image
results = model("images.jpeg")

# print result summary
print(results)

# save annotated result
annotated = results[0].plot()
cv2.imwrite("result.jpg", annotated)
# Out:
# WARNING Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt... Remote end closed connection without response
# WARNING Download failure, retrying 2/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt... Curl return value 35
# WARNING Download failure, retrying 3/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt... Curl return value 35
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\utils\downloads.py:329, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     328 r = subprocess.run(["curl", "-#", f"-{s}L", url, "-o", f, "--retry", "3", "-C", "-"]).returncode
# --> 329 assert r == 0, f"Curl return value {r}"
#     330 expected_size = None  # Can't get size with curl
#
# AssertionError: Curl return value 35
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 5
#       2 import cv2
#       4 # load pretrained YOLOv8 nano model
# ----> 5 model = YOLO("yolov8n.pt")
#       7 # run inference on an image
#       8 results = model("images.jpeg")
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
#     142     self._new(model, task=task, verbose=verbose)
#     143 else:
# --> 144     self._load(model, task=task)
#     146 # Delete super().training for accessing self.model.training
#     147 del self.training
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\engine\model.py:283, in Model._load(self, weights, task)
#     280 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     282 if str(weights).rpartition(".")[-1] == "pt":
# --> 283     self.model, self.ckpt = load_checkpoint(weights)
#     284     self.task = self.model.task
#     285     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:1461, in load_checkpoint(weight, device, inplace, fuse)
#    1448 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1449     """Load a single model weights.
#    1450
#    1451     Args:
#    (...)
#    1459         ckpt (dict): Model checkpoint dictionary.
#    1460     """
# -> 1461     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1462     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1463     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:1387, in torch_safe_load(weight, safe_only)
#    1384 from ultralytics.utils.downloads import attempt_download_asset
#    1386 check_suffix(file=weight, suffix=".pt")
# -> 1387 file = attempt_download_asset(weight)  # search online if missing locally
#    1388 try:
#    1389     with temporary_modules(
#    1390         modules={
#    1391             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#    1399         },
#    1400     ):
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\utils\downloads.py:467, in attempt_download_asset(file, repo, release, **kwargs)
#     464         safe_download(url=url, file=file, min_bytes=1e5, **kwargs)
#     466 elif repo == GITHUB_ASSETS_REPO and name in GITHUB_ASSETS_NAMES:
# --> 467     safe_download(url=f"{download_url}/{release}/{name}", file=file, min_bytes=1e5, **kwargs)
#     469 else:
#     470     tag, assets = get_github_assets(repo, release)
#
# File d:\Anaconda\envs\yolov8\lib\site-packages\ultralytics\utils\downloads.py:370, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     368                 raise ConnectionError(emojis(f"❌  Download failure for {uri}. Environment may be offline.")) from e
#     369             elif i >= retry:
# --> 370                 raise ConnectionError(emojis(f"❌  Download failure for {uri}. Retry limit reached. {e}")) from e
#     371             LOGGER.warning(f"Download failure, retrying {i + 1}/{retry} {uri}... {e}")
#     373 if unzip and f.exists() and f.suffix in {"", ".zip", ".tar", ".gz"}:
#
# ConnectionError:   Download failure for https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt. Retry limit reached. Curl return value 35

# %%
import cv2
import time
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture(0)

while True:
    t0 = time.time()
    ret, frame = cap.read()
    if not ret:
        break
    
    results = model(frame, verbose=False)[0]
    annotated = results.plot()

    latency_ms = (time.time() - t0) * 1000
    cv2.putText(annotated, f"{latency_ms:.1f} ms",
                (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1,
                (0,255,0), 2)

    cv2.imshow("YOLO Webcam", annotated)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
